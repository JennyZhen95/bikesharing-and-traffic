# %% [markdown]
# # Find the neighborhood a coordinate falls within
# #### Author: Jenny Zhen
# #### Nov 6th, 2019
#
# #### Note:
# 1. The coordinate points need to be formatted as (longitude, latitude).

# %% [markdown]
# ## Function

# %%
# Import following packages.
import fiona
from shapely.geometry import shape,mapping, Point, Polygon, MultiPolygon
import pandas as pd
import numpy as np

# %%
def find_neighborhood(neighborhood, lat, long):
    """
    Find the neighborhood where each coordinate in a list falls within. Remember to import
    packages above first.
    
    Note: Point in this funciton is formatted as (long, lat). 
    
    Parameters:
    --------------------
    neighborhood:    string
                     String of data path and file name. The file should be a shape file containing 
                     neighborhood name and boundary coordinates. Check which dictionary keys to 
                     call for shaping polygon and neighborhood name.
    
    lat:             pd.Series
                     The latitude column of a panda dataframe which we need to find the neighborhood for.
                     
    long:            pd.Series
                     The longitude column of a panda dataframe which we need to find the neighborhood for.
                     
                     
    
    Return:
    --------------------
    neigh_names:     list
                     The names of neighborhoods where each pair of lat and long lies within.
                     
    """
    neigh_names = []
    multipol = fiona.open(neighborhood)
    for i in range(0,len(lat)):
        # Point in this case is formatted as (long, lat). 
        point = Point(long[i], lat[i])
        
        counter = 0
        for feat in multipol:
            if point.within(shape(feat['geometry'])):
                neigh_names.append(feat['properties']['pri_neigh'])
                counter +=1
                
        # If point does not find any neighborhood, return nan
        if counter == 0:
            neigh_names.append(np.nan)
            
                
                
    return(neigh_names)

# %% [markdown]
# ## Find neighborhoods for datasets

# %% [markdown]
# ### Station

# %%
station = pd.read_csv('stations.csv')

# %%
station['neighborhood'] = find_neighborhood("geo_export_cdc4661f-83bd-40ef-9034-c4bdb778cf15.shp", station['lat'], station['long'])

# %%
# Some bike stations are out of scope in terms of searching neighborhood. 
sum(station['neighborhood_id'].isna())
# Out:
# 14

# %%
# Substitue neighborhood name with id.
neighborhood = pd.read_csv('neighborhood.csv')

station = station.merge(neighborhood, left_on = 'neighborhood', right_on = 'name', how='left')
station.drop(['name', 'neighborhood'], axis = 1, inplace=True)

# %%
station['neighborhood_id'] = station['neighborhood_id'].astype('Int64')

# %%
station.to_csv('stations.csv', index=False)

# %% [markdown]
# ### Segment
#
# 1. Data has start neighborhood and end neighborhood.  1046 rows
# 2. If start and/or end neighborhoods are out of scope, then delete entire row. 963 rows
# 3. Keep segments where start_neigh equals to end_neigh. 609 rows

# %%
seg = pd.read_csv('segments.csv')

# %%
seg['start_neigh'] = find_neighborhood("geo_export_cdc4661f-83bd-40ef-9034-c4bdb778cf15.shp", seg['START_LATITUDE'], seg['START_LONGITUDE'])
seg['end_neigh'] = find_neighborhood("geo_export_cdc4661f-83bd-40ef-9034-c4bdb778cf15.shp", seg['END_LATITUDE'], seg['END_LONGITUDE'])

# %%
seg = seg.merge(neighborhood, left_on = 'start_neigh', right_on = 'name', how = 'left')

seg.rename(columns = {'neighborhood_id': 'start_neigh_id'}, inplace=True)

seg.drop(['start_neigh', 'name'], axis = 1, inplace=True)

seg = seg.merge(neighborhood, left_on = 'end_neigh', right_on = 'name', how = 'left')

seg.rename(columns = {'neighborhood_id': 'end_neigh_id'}, inplace = True)

seg.drop(['end_neigh', 'name'], axis=1, inplace=True)

# %%
seg.to_csv('segments.csv', index=False)

# %% [markdown]
# ### Crash

# %%
crash = pd.read_csv('/Users/Jenny/Downloads/Clean_Crash.csv')

# %%
crash.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
crash['neighborhood'] = find_neighborhood("geo_export_cdc4661f-83bd-40ef-9034-c4bdb778cf15.shp", crash['LATITUDE'], crash['LONGITUDE'])

# %%
crash.to_csv('crash_backup.csv', index=False)

# %%
neighborhood = pd.read_csv('neighborhood.csv')

crash = crash.merge(neighborhood, left_on = 'neighborhood', right_on = 'name', how='left')
crash.drop(['name', 'neighborhood'], axis = 1, inplace=True)

# %%
crash['neighborhood_id'] = crash['neighborhood_id'].astype('Int64')

# %%
crash.to_csv('crash.csv', index=False)

# %% [markdown]
# ## Export all neighborhoods as csv with its id.

# %%
df = fiona.open("/Users/Jenny/Desktop/MSCA/Data Engineering/Project/Boundaries - Neighborhoods/Boundaries - Neighborhoods/geo_export_c0182ca0-1f35-4cb2-b1bd-75b05d26853c.shp")

# %%
for feat in df:
    print(feat['properties']['pri_neigh'])
# Out:
# Grand Boulevard
# Printers Row
# United Center
# Sheffield & DePaul
# Humboldt Park
# Garfield Park
# North Lawndale
# Little Village
# Armour Square
# Avalon Park
# Burnside
# Hermosa
# Avondale
# Logan Square
# Calumet Heights
# East Side
# West Pullman
# Garfield Ridge
# New City
# Englewood
# Grand Crossing
# Ashburn
# Mount Greenwood
# Morgan Park
# O'Hare
# Jackson Park
# Loop
# Pullman
# Riverdale
# Hegewisch
# Greektown
# Douglas
# Museum Campus
# Edgewater
# Lake View
# Lincoln Park
# Magnificent Mile
# Lincoln Square
# Oakland
# Grant Park
# West Loop
# Fuller Park
# Andersonville
# Woodlawn
# Portage Park
# Rush & Division
# Little Italy, UIC
# Kenwood
# Rogers Park
# Jefferson Park
# Sauganash,Forest Glen
# North Park
# Albany Park
# Irving Park
# Dunning
# West Ridge
# Uptown
# Norwood Park
# Streeterville
# South Shore
# Chatham
# South Chicago
# Roseland
# North Center
# South Deering
# Washington Park
# Millenium Park
# Near South Side
# Chinatown
# Chicago Lawn
# Auburn Gresham
# Beverly
# Washington Heights
# Edison Park
# Hyde Park
# Bucktown
# Lower West Side
# Wrigleyville
# Archer Heights
# Brighton Park
# Mckinley Park
# East Village
# West Town
# Bridgeport
# West Elsdon
# Gage Park
# Clearing
# West Lawn
# Wicker Park
# Ukrainian Village
# Galewood
# Montclare
# Old Town
# Belmont Cragin
# Austin
# Gold Coast
# Boystown
# River North

# %%
df.next()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   """Entry point for launching an IPython kernel.
# {'type': 'Feature',
#  'id': '0',
#  'properties': OrderedDict([('pri_neigh', 'Grand Boulevard'),
#               ('sec_neigh', 'BRONZEVILLE'),
#               ('shape_area', 48492503.1554),
#               ('shape_len', 28196.837157)]),
#  'geometry': {'type': 'Polygon',
#   'coordinates': [
#     (-87.61514774091994, 41.82385938205802),
#     (-87.61436403577905, 41.82386898820399),
#     (-87.61307586545516, 41.82388477628119),
#     (-87.6126242723945, 41.82389080517135),
#     (-87.61213605331174, 41.82389732077577),
#     (-87.60984136661733, 41.82392073796532),
#     (-87.60958706836169, 41.8239233302702),
#     (-87.60833773776247, 41.823936856818634),
#     (-87.60732734037146, 41.823948916418225),
#     (-87.60702859187904, 41.82395794994388),
#     (-87.60691604357245, 41.823960064818166),
#     (-87.60687961339802, 41.82396315498523),
#     (-87.60687305832275, 41.82396480097776),
#     (-87.60643720434108, 41.82330608474624),
#     (-87.60685918571652, 41.82316570805976),
#     (-87.60685533006003, 41.822728573039406),
#     (-87.6068526488037, 41.82242460254308),
#     (-87.60684690560025, 41.82212653863883),
#     (-87.60684469473264, 41.82201181422022),
#     (-87.6068329651238, 41.82150286969486),
#     (-87.60682337846411, 41.82108691561883),
#     (-87.60682020393564, 41.82095602353345),
#     (-87.60680883367007, 41.820487201035306),
#     (-87.60680628352334, 41.820382051664296),
#     (-87.60680354977386, 41.82026932337828),
#     (-87.60679873015552, 41.82007061161064),
#     (-87.60677170452449, 41.81957187461968),
#     (-87.60677170420108, 41.81957187077567),
#     (-87.60676659017096, 41.819477492620884),
#     (-87.60676036316822, 41.81934471563506),
#     (-87.6067528264812, 41.81907881651855),
#     (-87.60675342900633, 41.81903960031779),
#     (-87.60675297509786, 41.81882502734551),
#     (-87.60674996732051, 41.8186183880878),
#     (-87.60674735823706, 41.81843914739708),
#     (-87.60674518638625, 41.81830998828799),
#     (-87.60674253234453, 41.81815212105517),
#     (-87.60673501624129, 41.81794403035113),
#     (-87.60672984729013, 41.817800911376665),
#     (-87.60672784818331, 41.817732933571186),
#     (-87.60672652161489, 41.817687826656055),
#     (-87.60672120877406, 41.817507137421366),
#     (-87.60671660883158, 41.817290969540544),
#     (-87.60671188120513, 41.81707957587562),
#     (-87.60670812560372, 41.816813771373916)]]}}

# %%
neighborhood = pd.DataFrame({'neighborhood_id':[], 'name':[]})

for feat in df:
    neighborhood = neighborhood.append({'neighborhood_id':feat['id'], 'name':feat['properties']['pri_neigh']}
                       , ignore_index=True)

# %%
neighborhood.to_csv('neighborhood.csv', index=False)

# %%
neighborhood=pd.read_csv('/Users/Jenny/Desktop/MSCA/Data Engineering/Project/Boundaries - Neighborhoods/neighborhood.csv')

# %%
for i in range(0,len(neighborhood)):
        print("UPDATE neighborhood SET NAME = '{}' WHERE neighborhood_id = {};".format(neighborhood['name'][i], neighborhood['neighborhood_id'][i]))
# Out:
# UPDATE neighborhood SET NAME = 'Grand Boulevard' WHERE neighborhood_id = 1;
# UPDATE neighborhood SET NAME = 'Printers Row' WHERE neighborhood_id = 2;
# UPDATE neighborhood SET NAME = 'United Center' WHERE neighborhood_id = 3;
# UPDATE neighborhood SET NAME = 'Sheffield & DePaul' WHERE neighborhood_id = 4;
# UPDATE neighborhood SET NAME = 'Humboldt Park' WHERE neighborhood_id = 5;
# UPDATE neighborhood SET NAME = 'Garfield Park' WHERE neighborhood_id = 6;
# UPDATE neighborhood SET NAME = 'North Lawndale' WHERE neighborhood_id = 7;
# UPDATE neighborhood SET NAME = 'Little Village' WHERE neighborhood_id = 8;
# UPDATE neighborhood SET NAME = 'Armour Square' WHERE neighborhood_id = 9;
# UPDATE neighborhood SET NAME = 'Avalon Park' WHERE neighborhood_id = 10;
# UPDATE neighborhood SET NAME = 'Burnside' WHERE neighborhood_id = 11;
# UPDATE neighborhood SET NAME = 'Hermosa' WHERE neighborhood_id = 12;
# UPDATE neighborhood SET NAME = 'Avondale' WHERE neighborhood_id = 13;
# UPDATE neighborhood SET NAME = 'Logan Square' WHERE neighborhood_id = 14;
# UPDATE neighborhood SET NAME = 'Calumet Heights' WHERE neighborhood_id = 15;
# UPDATE neighborhood SET NAME = 'East Side' WHERE neighborhood_id = 16;
# UPDATE neighborhood SET NAME = 'West Pullman' WHERE neighborhood_id = 17;
# UPDATE neighborhood SET NAME = 'Garfield Ridge' WHERE neighborhood_id = 18;
# UPDATE neighborhood SET NAME = 'New City' WHERE neighborhood_id = 19;
# UPDATE neighborhood SET NAME = 'Englewood' WHERE neighborhood_id = 20;
# UPDATE neighborhood SET NAME = 'Grand Crossing' WHERE neighborhood_id = 21;
# UPDATE neighborhood SET NAME = 'Ashburn' WHERE neighborhood_id = 22;
# UPDATE neighborhood SET NAME = 'Mount Greenwood' WHERE neighborhood_id = 23;
# UPDATE neighborhood SET NAME = 'Morgan Park' WHERE neighborhood_id = 24;
# UPDATE neighborhood SET NAME = 'O'Hare' WHERE neighborhood_id = 25;
# UPDATE neighborhood SET NAME = 'Jackson Park' WHERE neighborhood_id = 26;
# UPDATE neighborhood SET NAME = 'Loop' WHERE neighborhood_id = 27;
# UPDATE neighborhood SET NAME = 'Pullman' WHERE neighborhood_id = 28;
# UPDATE neighborhood SET NAME = 'Riverdale' WHERE neighborhood_id = 29;
# UPDATE neighborhood SET NAME = 'Hegewisch' WHERE neighborhood_id = 30;
# UPDATE neighborhood SET NAME = 'Greektown' WHERE neighborhood_id = 31;
# UPDATE neighborhood SET NAME = 'Douglas' WHERE neighborhood_id = 32;
# UPDATE neighborhood SET NAME = 'Museum Campus' WHERE neighborhood_id = 33;
# UPDATE neighborhood SET NAME = 'Edgewater' WHERE neighborhood_id = 34;
# UPDATE neighborhood SET NAME = 'Lake View' WHERE neighborhood_id = 35;
# UPDATE neighborhood SET NAME = 'Lincoln Park' WHERE neighborhood_id = 36;
# UPDATE neighborhood SET NAME = 'Magnificent Mile' WHERE neighborhood_id = 37;
# UPDATE neighborhood SET NAME = 'Lincoln Square' WHERE neighborhood_id = 38;
# UPDATE neighborhood SET NAME = 'Oakland' WHERE neighborhood_id = 39;
# UPDATE neighborhood SET NAME = 'Grant Park' WHERE neighborhood_id = 40;
# UPDATE neighborhood SET NAME = 'West Loop' WHERE neighborhood_id = 41;
# UPDATE neighborhood SET NAME = 'Fuller Park' WHERE neighborhood_id = 42;
# UPDATE neighborhood SET NAME = 'Andersonville' WHERE neighborhood_id = 43;
# UPDATE neighborhood SET NAME = 'Woodlawn' WHERE neighborhood_id = 44;
# UPDATE neighborhood SET NAME = 'Portage Park' WHERE neighborhood_id = 45;
# UPDATE neighborhood SET NAME = 'Rush & Division' WHERE neighborhood_id = 46;
# UPDATE neighborhood SET NAME = 'Little Italy, UIC' WHERE neighborhood_id = 47;
# UPDATE neighborhood SET NAME = 'Kenwood' WHERE neighborhood_id = 48;
# UPDATE neighborhood SET NAME = 'Rogers Park' WHERE neighborhood_id = 49;
# UPDATE neighborhood SET NAME = 'Jefferson Park' WHERE neighborhood_id = 50;
# UPDATE neighborhood SET NAME = 'Sauganash,Forest Glen' WHERE neighborhood_id = 51;
# UPDATE neighborhood SET NAME = 'North Park' WHERE neighborhood_id = 52;
# UPDATE neighborhood SET NAME = 'Albany Park' WHERE neighborhood_id = 53;
# UPDATE neighborhood SET NAME = 'Irving Park' WHERE neighborhood_id = 54;
# UPDATE neighborhood SET NAME = 'Dunning' WHERE neighborhood_id = 55;
# UPDATE neighborhood SET NAME = 'West Ridge' WHERE neighborhood_id = 56;
# UPDATE neighborhood SET NAME = 'Uptown' WHERE neighborhood_id = 57;
# UPDATE neighborhood SET NAME = 'Norwood Park' WHERE neighborhood_id = 58;
# UPDATE neighborhood SET NAME = 'Streeterville' WHERE neighborhood_id = 59;
# UPDATE neighborhood SET NAME = 'South Shore' WHERE neighborhood_id = 60;
# UPDATE neighborhood SET NAME = 'Chatham' WHERE neighborhood_id = 61;
# UPDATE neighborhood SET NAME = 'South Chicago' WHERE neighborhood_id = 62;
# UPDATE neighborhood SET NAME = 'Roseland' WHERE neighborhood_id = 63;
# UPDATE neighborhood SET NAME = 'North Center' WHERE neighborhood_id = 64;
# UPDATE neighborhood SET NAME = 'South Deering' WHERE neighborhood_id = 65;
# UPDATE neighborhood SET NAME = 'Washington Park' WHERE neighborhood_id = 66;
# UPDATE neighborhood SET NAME = 'Millenium Park' WHERE neighborhood_id = 67;
# UPDATE neighborhood SET NAME = 'Near South Side' WHERE neighborhood_id = 68;
# UPDATE neighborhood SET NAME = 'Chinatown' WHERE neighborhood_id = 69;
# UPDATE neighborhood SET NAME = 'Chicago Lawn' WHERE neighborhood_id = 70;
# UPDATE neighborhood SET NAME = 'Auburn Gresham' WHERE neighborhood_id = 71;
# UPDATE neighborhood SET NAME = 'Beverly' WHERE neighborhood_id = 72;
# UPDATE neighborhood SET NAME = 'Washington Heights' WHERE neighborhood_id = 73;
# UPDATE neighborhood SET NAME = 'Edison Park' WHERE neighborhood_id = 74;
# UPDATE neighborhood SET NAME = 'Hyde Park' WHERE neighborhood_id = 75;
# UPDATE neighborhood SET NAME = 'Bucktown' WHERE neighborhood_id = 76;
# UPDATE neighborhood SET NAME = 'Lower West Side' WHERE neighborhood_id = 77;
# UPDATE neighborhood SET NAME = 'Wrigleyville' WHERE neighborhood_id = 78;
# UPDATE neighborhood SET NAME = 'Archer Heights' WHERE neighborhood_id = 79;
# UPDATE neighborhood SET NAME = 'Brighton Park' WHERE neighborhood_id = 80;
# UPDATE neighborhood SET NAME = 'Mckinley Park' WHERE neighborhood_id = 81;
# UPDATE neighborhood SET NAME = 'East Village' WHERE neighborhood_id = 82;
# UPDATE neighborhood SET NAME = 'West Town' WHERE neighborhood_id = 83;
# UPDATE neighborhood SET NAME = 'Bridgeport' WHERE neighborhood_id = 84;
# UPDATE neighborhood SET NAME = 'West Elsdon' WHERE neighborhood_id = 85;
# UPDATE neighborhood SET NAME = 'Gage Park' WHERE neighborhood_id = 86;
# UPDATE neighborhood SET NAME = 'Clearing' WHERE neighborhood_id = 87;
# UPDATE neighborhood SET NAME = 'West Lawn' WHERE neighborhood_id = 88;
# UPDATE neighborhood SET NAME = 'Wicker Park' WHERE neighborhood_id = 89;
# UPDATE neighborhood SET NAME = 'Ukrainian Village' WHERE neighborhood_id = 90;
# UPDATE neighborhood SET NAME = 'Galewood' WHERE neighborhood_id = 91;
# UPDATE neighborhood SET NAME = 'Montclare' WHERE neighborhood_id = 92;
# UPDATE neighborhood SET NAME = 'Old Town' WHERE neighborhood_id = 93;
# UPDATE neighborhood SET NAME = 'Belmont Cragin' WHERE neighborhood_id = 94;
# UPDATE neighborhood SET NAME = 'Austin' WHERE neighborhood_id = 95;
# UPDATE neighborhood SET NAME = 'Gold Coast' WHERE neighborhood_id = 96;
# UPDATE neighborhood SET NAME = 'Boystown' WHERE neighborhood_id = 97;
# UPDATE neighborhood SET NAME = 'River North' WHERE neighborhood_id = 98;

# %%
neighborhood
# Out:
#     neighborhood_id                name
# 0                 0     Grand Boulevard
# 1                 1        Printers Row
# 2                 2       United Center
# 3                 3  Sheffield & DePaul
# 4                 4       Humboldt Park
# 5                 5       Garfield Park
# 6                 6      North Lawndale
# 7                 7      Little Village
# 8                 8       Armour Square
# 9                 9         Avalon Park
# 10               10            Burnside
# 11               11             Hermosa
# 12               12            Avondale
# 13               13        Logan Square
# 14               14     Calumet Heights
# 15               15           East Side
# 16               16        West Pullman
# 17               17      Garfield Ridge
# 18               18            New City
# 19               19           Englewood
# 20               20      Grand Crossing
# 21               21             Ashburn
# 22               22     Mount Greenwood
# 23               23         Morgan Park
# 24               24              O'Hare
# 25               25        Jackson Park
# 26               26                Loop
# 27               27             Pullman
# 28               28           Riverdale
# 29               29           Hegewisch
# ..              ...                 ...
# 68               68           Chinatown
# 69               69        Chicago Lawn
# 70               70      Auburn Gresham
# 71               71             Beverly
# 72               72  Washington Heights
# 73               73         Edison Park
# 74               74           Hyde Park
# 75               75            Bucktown
# 76               76     Lower West Side
# 77               77        Wrigleyville
# 78               78      Archer Heights
# 79               79       Brighton Park
# 80               80       Mckinley Park
# 81               81        East Village
# 82               82           West Town
# 83               83          Bridgeport
# 84               84         West Elsdon
# 85               85           Gage Park
# 86               86            Clearing
# 87               87           West Lawn
# 88               88         Wicker Park
# 89               89   Ukrainian Village
# 90               90            Galewood
# 91               91           Montclare
# 92               92            Old Town
# 93               93      Belmont Cragin
# 94               94              Austin
# 95               95          Gold Coast
# 96               96            Boystown
# 97               97         River North
#
# [98 rows x 2 columns]
